# %% [markdown]
# <a href="https://colab.research.google.com/github/BaronMiau/AI-Kurs/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **siema**

# %%
print("Hello world")
# Out:
# Hello world
