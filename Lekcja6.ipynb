# %% [markdown]
# <a href="https://colab.research.google.com/github/BaronMiau/AI-Kurs/blob/main/Lekcja6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **siema**

# %%
print("Hello world")
# Out:
# Hello world

# %%
num = 11234
text = "Goodbye world"
bool_variable = False
float_num = 14.352

print(f"liczba: {num}, średnia {float_num}")
print(type(num))

games= ["Portal 2", "Team Fortress 2", "Counter Strike: Global Offensive"]
print(games[2])

games.append("CS2")
print(games[3])

print(int("11110000", 2))

temperature = float(input("Podaj dowolną temperaturę:"))
if temperature < 22:
  print("Temperatura +")
elif temperature > 25:
  print("Wylaczam sie")
else:
  print("Temperatura normalna")


for game in games:
  print(game)

for i in range(-8, 100, 3):
  print(i)
# Out:
# liczba: 11234, średnia 14.352
# <class 'int'>
# Counter Strike: Global Offensive
# CS2
# 240
# Podaj dowolną temperaturę:12
# Temperatura +
# Portal 2
# Team Fortress 2
# Counter Strike: Global Offensive
# CS2
# -8
# -5
# -2
# 1
# 4
# 7
# 10
# 13
# 16
# 19
# 22
# 25
# 28
# 31
# 34
# 37
# 40
# 43
# 46
# 49
# 52
# 55
# 58
# 61
# 64
# 67
# 70
# 73
# 76
# 79
# 82
# 85
# 88
# 91
# 94
# 97
